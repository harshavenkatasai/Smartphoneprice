# %% [markdown]
# ###Data Access from DataLake

# %%
spark.conf.set("fs.azure.account.auth.type.onedatalakeg2storage.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.onedatalakeg2storage.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.onedatalakeg2storage.dfs.core.windows.net", "b5206394-0813-4397-8981-4f10d299262c")
spark.conf.set("fs.azure.account.oauth2.client.secret.onedatalakeg2storage.dfs.core.windows.net", "T9t8Q~PhZU_RZgeilj2lBZCaQx_HyirqZHIUnc9-")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.onedatalakeg2storage.dfs.core.windows.net", "https://login.microsoftonline.com/8b8e27df-59e2-4292-b0e1-f0c70ad2b5d8/oauth2/token")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pyspark.sql as sql
import math

# %%
df_Ogl=spark.read.format("csv").option("header","true").option("inferSchema","true").load("abfss://bronze-layer@onedatalakeg2storage.dfs.core.windows.net/Doc/Mobiles.csv")

# %%
df_copy = df_Ogl.toPandas().copy()

# %%
# df_copy.display()
# df_copy.head(5)
# df_copy.describe()
# df_copy.info()
# df_copy.duplicated().sum()
# df_copy.isnull().sum()
# df_copy['Company Name'].value_counts()
# df_copy['Model Name'].value_counts()
# df_copy['Mobile Weight'].value_counts()
# df_copy.shape()

# %%
type(df_copy)
# Out:
# pandas.core.frame.DataFrame

# %%
df_copy = df_copy.rename(columns={"Company Name":"Company_Name","Model Name":"Model_Name","Mobile Weight":"Mobile_Weight","RAM":"RAM","Front Camera":"Front_Camera","Back Camera":"Back_Camera","Processor":"Processor","Battery Capacity":"Battery_Capacity","Screen Size":"Screen_Size","Launched Price (Pakistan)":"Launched_Price_Pakistan","Launched Price (India)":"Launched_Price_India","Launched Price (China)":"Launched_Price_China","Launched Price (USA)":"Launched_Price_USA","Launched Price (Dubai)":"Launched_Price_Dubai","Launched Year":"Launched_Year"})

# %%
df_copy.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_copy=spark.createDataFrame(df_copy)

# %%
df_copy = df_copy.withColumn("Count_of_Back_cam", sql.functions.expr("length(Back_Camera) - length(replace(Back_Camera, '+', '')) + 1"))
df_copy = df_copy.withColumn("Count_of_front_cam", sql.functions.expr("length(Front_Camera) - length(replace(Front_Camera, '+', '')) + 1"))

# %%
df_copy.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_copy.write.mode("append").format("parquet").option("path","abfss://silver-layer@onedatalakeg2storage.dfs.core.windows.net/Mobiles").save()

# %%
df_copy.groupBy("Company_Name").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_copy.groupBy("Processor").count().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
